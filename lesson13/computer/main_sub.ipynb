# %%
import os
os.path.abspath(__name__)
#os.path.realpath(__file__)
root_dir = os.getcwd()
data_dir = os.path.join(root_dir, 'data')
data_dir
if not os.path.isdir(data_dir):
    os.mkdir('data')

# %%
from datetime import datetime
today = datetime.today()
filename = today.strftime("%Y-%m-%d") + ".csv"
#get_file_abspath
full_path = os.path.join(data_dir,filename)
full_path
# Out:
# 'c:\\Users\\User\\Documents\\GitHub\\raspberry\\lesson13\\computer\\data\\2024-10-12.csv'

# %%
if not os.path.exists(full_path) :
    #沒有這個檔，所以要建立檔案
    print('沒有這個檔')
    with open(full_path,mode='w',encoding='utf-8',newline='') as file:
            file.write('時間,設備,值\n')
else:
    print('此檔名已存在')
# Out:
# 此檔名已存在

# %%
from datetime import datetime
import csv
now = datetime.today()
now_str = now.strftime("%Y-%m-%d %H:%M:%S")
header = [now_str, 'SA-52/LED_LEVE', 5]
with open(full_path,mode='a',encoding='utf-8',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
