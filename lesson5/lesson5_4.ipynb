# %%
import random
import time

for i in range(100):
    print(random.randint(1,10))
    time.sleep(1)
# Out:
# 2

# %%
import requests
r = requests.get(url='https://api.github.com/events')
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41926801636","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":365756231,"name":"Arumi09/Arumi09","url":"https://api.github.com/repos/Arumi09/Arumi09"},"payload":{"repository_id":365756231,"push_id":20235320274,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"82009c510757778ad8c72a82690d22fcc9c509cc","before":"42d2cb2ba2ba37d37c292d22a648a44da3f4940f","commits":[{"sha":"82009c510757778ad8c72a82690d22fcc9c509cc","author":{"email":"Arumi09@users.noreply.github.com","name":"Arumi09"},"message":"Update README","distinct":true,"url":"https://api.github.com/repos/Arumi09/Arumi09/commits/82009c510757778ad8c72a82690d22fcc9c509cc"}]},"public":true,"created_at":"2024-09-14T07:48:05Z"},{"id":"41926801638","type":"DeleteEvent","actor":{"id":143372403,"login":"yukareto","di
# ...
